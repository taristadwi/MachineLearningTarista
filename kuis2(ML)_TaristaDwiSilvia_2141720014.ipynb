# %% [markdown]
# <a href="https://colab.research.google.com/github/taristadwi/MachineLearningTarista/blob/main/kuis2(ML)_TaristaDwiSilvia_2141720014.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Nama:Tarista Dwi Silvia**
#
# # **NIM:2141720014**
#
# # **Kelas:TI-3A**

# %% [markdown]
# Langkah Pertama
# Menginstall library Pytesseract untuk OCR di Python dan
# Menginstall OCR Tesseract versi bahasa Indonesia
# Sehingga kita bisa menggunakan fitur OCR untuk bahasa Indonesia di script Python menggunakan Pytesseract.

# %%
# !pip install pytesseract
# !sudo apt-get install tesseract-ocr-ind
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-ind is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.

# %% [markdown]
# Langkah selanjutnya mengimport semua library yang dibutuhkan untuk memanipulasi citra digital (OpenCV), memvisualisasikan citra (Matplotlib), melakukan OCR (Pytesseract), dan mengakses file system (OS).

# %%
import cv2
import matplotlib.pyplot as plt
import pytesseract
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Langkah selanjutnya membaca gambar dari direktori kemudian mengonversi warnanya dari BGR ke RGB, lalu menampilkannya dengan matplotlib dengan judul "Gambar Asli".

# %%
# Plot gambar original

# Membaca gambar dari direktori
image = cv2.imread('/content/drive/MyDrive/ML/Kuis2/KTP_Tarista Dwi Silvia.jpeg')

# Memisahkan saluran warna (blue, green, red) karena matplotlib menggunakan skema warna RGB
b, g, r = cv2.split(image)
rgb_img = cv2.merge([r, g, b])

# Menampilkan gambar dalam ukuran tertentu
plt.figure(figsize=(8, 6))
plt.imshow(rgb_img)
plt.title('Gambar Asli')
plt.show()

# %%
# Membaca citra menggunakan fungsi cv2.imread(). Parameter kedua 0 menginstruksikan untuk membaca gambar dalam skala keabuan
img = cv2.imread('/content/drive/MyDrive/ML/Kuis2/KTP_Tarista Dwi Silvia.jpeg', 0)

# Melakukan thresholding biner pada citra keabuan. Nilai threshold adalah 127 dan nilai putih 255. Hasil thresholding disimpan ke variabel thresh.
ret, thresh = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

# Membuat kernel morfologi 3x3 dan menerapkannya untuk melakukan erosi pada citra hasil threshold sebanyak 1 kali iterasi.
kernel = np.ones((3, 3), np.uint8)
eroded = cv2.erode(thresh, kernel, iterations=1)

# Menampilkan citra keabuan img pada subplot pertama dari figure matplotlib, dengan ukuran tertentu dan berbagai konfigurasi lainnya.
plt.figure(figsize=(20, 6))
plt.subplot(1, 3, 1), plt.imshow(img, cmap='gray')
plt.title('Citra Asli'), plt.xticks([]), plt.yticks([])

# Menampilkan citra asli dan hasil thresholding dengan matplotlib subplot satu baris dua kolom.
plt.subplot(1, 3, 2), plt.imshow(thresh, cmap='gray')
plt.title('Citra Hasil Thresholding'), plt.xticks([]), plt.yticks([])

plt.show()

# Ekstrak teks dari citra hasil thresholding
extracted_text = pytesseract.image_to_string(wa_thresholded, lang="ind")

# Tampilkan teks yang diekstrak
print("\nHasil Ekstrak Teks\n\n"+extracted_text)
# Out:
# Hasil Ekstrak Teks
#
# PROVINSI JAWA TIMUR
#
# KABUPATEN MALANG
# NIK : 350725416505020006
# Nama 1 TARISTA DWI SILVIA
# Tempat/Tgi Lahir : MALANG, 06-05-2002
# Jenis kelamin :PEREMPUAN Gol. Darah :-
# Alamat 1 JL BIMA SAKTHI
# RT/RW 1 907906
#
# KelDesa : BEBALI
# Kecamatan : LAWANG
# ISLAM
#
# Agama
#
# Status Perkawinan: BELUM KAWIN
# Pekerjaan PELAJAR/MAHASISWA
# Kewarganegaraan
#
# Bertaku Hingga : SEUMUR HIDUP
